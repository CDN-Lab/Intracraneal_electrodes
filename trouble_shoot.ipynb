# %%
import import_ipynb
import input
import pandas as pd
# Accessing the parameters variable
patient_trials = pd.read_csv(input.patient_trials)
utility_analysis = input.utility_analysis
# Now you can use the parameters variable in your current notebook

# %%
patient_trials
# Out:
#      crdm_sure_amt  crdm_sure_p  crdm_lott_top  crdm_lott_bot  crdm_lott_p  \
# 0              5.0        100.0           40.0            0.0         50.0
# 1             -5.0        100.0            0.0           -8.0         75.0
# 2             -5.0        100.0            0.0          -40.0         75.0
# 3              5.0        100.0            0.0           50.0         25.0
# 4             -5.0        100.0          -20.0            0.0         75.0
# ..             ...          ...            ...            ...          ...
# 114           -5.0        100.0          -50.0            0.0         25.0
# 115            5.0        100.0           30.0            0.0         75.0
# 116           -5.0        100.0            0.0           -8.0         25.0
# 117           -5.0        100.0          -40.0            0.0         50.0
# 118            NaN          NaN            NaN            NaN          NaN
#
#      crdm_amb_lev crdm_domain          crdm_img crdm_win_side  \
# ...
